# %% [markdown]
# This notebook is meant to create some variables which can be played with manually for experimental purposes.

# %%
from FIAR import FIAR

# %% [markdown]
# Make a bunch of moves

# %%
game = FIAR()
game.move(0,0)
game.move(1,1)
game.move(2,2)
game.move(-1,-1)
game.move(1,-1)
game.move(-1,1)
game.move(0,2)
game.move(0,1)
game.move(2,1)
game.move(-3,1)
game.move(-2,1)
game.move(-2,0)

# %% [markdown]
# Extract some variables

# %%
df = game.df
display(df)
# Out:
#     marker    x    y player
# 0      1.0  0.0  0.0  black
# 1      2.0  1.0  1.0    red
# 2      3.0  2.0  2.0  black
# 3      4.0 -1.0 -1.0    red
# 4      5.0  1.0 -1.0  black
# 5      6.0 -1.0  1.0    red
# 6      7.0  0.0  2.0  black
# 7      8.0  0.0  1.0    red
# 8      9.0  2.0  1.0  black
# 9     10.0 -3.0  1.0    red
# 10    11.0 -2.0  1.0  black
# 11    12.0 -2.0  0.0    red

# %%
game.undo()

# %%
game.df[['x','y']].values
# Out:
# array([[ 0.,  0.],
#        [ 1.,  1.],
#        [ 2.,  2.],
#        [-1., -1.],
#        [ 1., -1.],
#        [-1.,  1.],
#        [ 0.,  2.],
#        [ 0.,  1.],
#        [ 2.,  1.],
#        [-3.,  1.],
#        [-2.,  1.]])
